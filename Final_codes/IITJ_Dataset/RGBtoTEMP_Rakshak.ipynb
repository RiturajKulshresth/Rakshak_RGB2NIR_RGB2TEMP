# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.callbacks import EarlyStopping

import cv2
import os
import tensorflow as tf
import random
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
import matplotlib.image as mpimg
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time
import h5py
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

import os
import pandas
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
import numpy as np

# %%
Data_dir="/home/netrunner/Downloads/RGB_temp"
Categories=["96", "97", "98"]
class_weight = {0: 12.,
                1: 1.,
                2: 2.}
Img_size=100
# new_array=cv.resize()
training_data=[]
def create_training_data():
    for category in Categories:
        path=os.path.join(Data_dir,category)
        class_number=Categories.index(category)
        for img in os.listdir(path):
            img_array=cv2.imread(os.path.join(path,img))
            new_array=cv2.resize(img_array,(Img_size,Img_size))
            training_data.append([new_array, class_number])
            
create_training_data()

# %%
# print(training_data)

# %%
random.shuffle(training_data)

# %%
X1=[]
Y1=[]
for features, label in training_data:
    X1.append(features)
    Y1.append(label)
    
    
X=np.array(X).reshape(-1,Img_size,Img_size,3)

# %%
# Y

# %%
X= np.asarray(X1)
Y= np.asarray(Y1)

# %%
dense_layers= [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3, 4, 5]


for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME= "Raks-{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            tensorboard= TensorBoard(log_dir='logs/{}'.format(NAME))
            
            model = Sequential()
            model.add(Conv2D(layer_size,(3,3), input_shape= X.shape[1:]))
            model.add(Activation("relu"))
            model.add(MaxPooling2D(pool_size=(2,2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size,(3,3)))
                model.add(Activation("relu"))
                model.add(MaxPooling2D(pool_size=(2,2)))

            model.add(Flatten())

            for d in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation("relu"))


#             model.add(Conv2D(64,(3,3)))
#             model.add(Activation("relu"))
#             model.add(MaxPooling2D(pool_size=(2,2)))



            model.add(Flatten())
            model.add(Dense(64))
            model.add(Activation('relu'))

            model.add(Dense(5))
            model.add(Activation('softmax'))


            model.compile(loss="sparse_categorical_crossentropy",optimizer = "adam", metrics= ["sparse_categorical_accuracy"])

            #change batch size when the data becomes large to somewhere in 20s
            model.fit(X,Y, batch_size=1, epochs=10, validation_split=0.15,class_weight=class_weight, callbacks=[tensorboard])
# Out:
# Raks-1-conv-32-nodes-0-dense-1618603771
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 2s 50ms/sample - loss: 781.6164 - sparse_categorical_accuracy: 0.1935 - val_loss: 47.4304 - val_sparse_categorical_accuracy: 0.5000
# Epoch 2/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 384.3196 - sparse_categorical_accuracy: 0.6452 - val_loss: 105.3082 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 71.0994 - sparse_categorical_accuracy: 0.6452 - val_loss: 50.9150 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 1s 33ms/sample - loss: 15.7010 - sparse_categorical_accuracy: 0.8065 - val_loss: 9.8786 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 1s 29ms/sample - loss: 15.8763 - sparse_categorical_accuracy: 0.9355 - val_loss: 3.6014 - val_sparse_categorical_accuracy: 0.8333
# Epoch 6/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 29.6605 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.5650 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.6027 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.6043 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.6044 - val_sparse_categorical_accuracy: 0.5000
# Raks-2-conv-32-nodes-0-dense-1618603781
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 58.9099 - sparse_categorical_accuracy: 0.3548 - val_loss: 0.4981 - val_sparse_categorical_accuracy: 0.8333
# Epoch 2/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 1.7618 - sparse_categorical_accuracy: 0.6774 - val_loss: 2.4685 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 0s 12ms/sample - loss: 0.2816 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.6172 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 0.3378 - sparse_categorical_accuracy: 0.9032 - val_loss: 2.9054 - val_sparse_categorical_accuracy: 0.5000
# Epoch 5/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 0.2502 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.4399 - val_sparse_categorical_accuracy: 0.6667
# Epoch 6/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 0.1376 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6645 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 0.0024 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8187 - val_sparse_categorical_accuracy: 0.6667
# Epoch 8/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 7.8936e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7729 - val_sparse_categorical_accuracy: 0.6667
# Epoch 9/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 4.7474e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7329 - val_sparse_categorical_accuracy: 0.6667
# Epoch 10/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 3.5380e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7191 - val_sparse_categorical_accuracy: 0.6667
# Raks-3-conv-32-nodes-0-dense-1618603786
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 18ms/sample - loss: 41.8109 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.3565 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 1.9369 - sparse_categorical_accuracy: 0.5161 - val_loss: 0.6900 - val_sparse_categorical_accuracy: 0.6667
# Epoch 3/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.6595 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.5176 - val_sparse_categorical_accuracy: 0.1667
# Epoch 4/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.5371 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.7870 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 0.9492 - sparse_categorical_accuracy: 0.7419 - val_loss: 2.0373 - val_sparse_categorical_accuracy: 0.5000
# Epoch 6/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.2623 - sparse_categorical_accuracy: 0.7097 - val_loss: 0.7483 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 0.5416 - sparse_categorical_accuracy: 0.9032 - val_loss: 2.6288 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 0.6171 - sparse_categorical_accuracy: 0.8387 - val_loss: 1.9796 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 1.5860 - sparse_categorical_accuracy: 0.7419 - val_loss: 1.9619 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.5832 - sparse_categorical_accuracy: 0.7097 - val_loss: 2.1087 - val_sparse_categorical_accuracy: 0.6667
# Raks-4-conv-32-nodes-0-dense-1618603789
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 20ms/sample - loss: 13.2114 - sparse_categorical_accuracy: 0.4516 - val_loss: 2.2547 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 7.5346 - sparse_categorical_accuracy: 0.2581 - val_loss: 2.2702 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.2845 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.6474 - val_sparse_categorical_accuracy: 0.5000
# Epoch 4/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 3.9087 - sparse_categorical_accuracy: 0.4839 - val_loss: 2.2974 - val_sparse_categorical_accuracy: 0.1667
# Epoch 5/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 1.8587 - sparse_categorical_accuracy: 0.7419 - val_loss: 2.3272 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.6270 - sparse_categorical_accuracy: 0.3226 - val_loss: 2.0943 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.9819 - sparse_categorical_accuracy: 0.7419 - val_loss: 1.9191 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.8853 - sparse_categorical_accuracy: 0.3871 - val_loss: 2.4367 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.8179 - sparse_categorical_accuracy: 0.4516 - val_loss: 2.0530 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 0.9547 - sparse_categorical_accuracy: 0.8387 - val_loss: 2.5645 - val_sparse_categorical_accuracy: 0.5000
# Raks-5-conv-32-nodes-0-dense-1618603792
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 23ms/sample - loss: 10.4855 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.8005 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.2659 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.9015 - val_sparse_categorical_accuracy: 0.6667
# Epoch 3/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.0553 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.2120 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 0s 8ms/sample - loss: 3.4539 - sparse_categorical_accuracy: 0.1935 - val_loss: 1.2198 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.1658 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.0095 - val_sparse_categorical_accuracy: 0.5000
# Epoch 6/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.3618 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.1744 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.8595 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.3379 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.6035 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.0899 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.6530 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.8458 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.7395 - sparse_categorical_accuracy: 0.5806 - val_loss: 1.7532 - val_sparse_categorical_accuracy: 0.5000
# Raks-1-conv-64-nodes-0-dense-1618603796
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 2s 67ms/sample - loss: 2655.4227 - sparse_categorical_accuracy: 0.1935 - val_loss: 78.6547 - val_sparse_categorical_accuracy: 0.8333
# Epoch 2/10
# 31/31 [==============================] - 2s 62ms/sample - loss: 812.0329 - sparse_categorical_accuracy: 0.6452 - val_loss: 10.1881 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 2s 57ms/sample - loss: 9.1618 - sparse_categorical_accuracy: 0.8387 - val_loss: 18.7201 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 2s 65ms/sample - loss: 7.2555 - sparse_categorical_accuracy: 0.8710 - val_loss: 11.3350 - val_sparse_categorical_accuracy: 0.8333
# Epoch 5/10
# 31/31 [==============================] - 2s 63ms/sample - loss: 3.1294 - sparse_categorical_accuracy: 0.9677 - val_loss: 61.5178 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 2s 57ms/sample - loss: 9.9982e-08 - sparse_categorical_accuracy: 1.0000 - val_loss: 65.4732 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 2s 56ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 65.5510 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/10
# 31/31 [==============================] - 2s 57ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 65.5540 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 2s 57ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 65.5541 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 2s 56ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 65.5541 - val_sparse_categorical_accuracy: 0.3333
# Raks-2-conv-64-nodes-0-dense-1618603814
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 352.9347 - sparse_categorical_accuracy: 0.4516 - val_loss: 3.4549 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 56.6915 - sparse_categorical_accuracy: 0.5806 - val_loss: 2.0779 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 2.2929 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.7485 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 3.5509 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.8465 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 0.7912 - sparse_categorical_accuracy: 0.8065 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8333
# Epoch 6/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 6.7834 - sparse_categorical_accuracy: 0.8065 - val_loss: 2.8432 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 1.1184 - sparse_categorical_accuracy: 0.8387 - val_loss: 3.1157 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 0.3291 - sparse_categorical_accuracy: 0.9032 - val_loss: 7.4726 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 0.2456 - sparse_categorical_accuracy: 0.9355 - val_loss: 1.5088 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 0.0517 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0051 - val_sparse_categorical_accuracy: 0.5000
# Raks-3-conv-64-nodes-0-dense-1618603822
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 39.7125 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.2585 - val_sparse_categorical_accuracy: 0.5000
# Epoch 2/10
# 31/31 [==============================] - 1s 16ms/sample - loss: 6.0928 - sparse_categorical_accuracy: 0.2581 - val_loss: 2.0223 - val_sparse_categorical_accuracy: 0.6667
# Epoch 3/10
# 31/31 [==============================] - 1s 16ms/sample - loss: 2.2573 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.4958 - val_sparse_categorical_accuracy: 0.5000
# Epoch 4/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 3.8240 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.5538 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 0.9625 - sparse_categorical_accuracy: 0.7097 - val_loss: 1.1113 - val_sparse_categorical_accuracy: 0.6667
# Epoch 6/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 3.5763 - sparse_categorical_accuracy: 0.8710 - val_loss: 2.9822 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 2.0780 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.6472 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 3.1485 - sparse_categorical_accuracy: 0.7097 - val_loss: 1.3422 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 1.3255 - sparse_categorical_accuracy: 0.6774 - val_loss: 3.9050 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 1.1172 - sparse_categorical_accuracy: 0.6452 - val_loss: 4.8606 - val_sparse_categorical_accuracy: 0.3333
# Raks-4-conv-64-nodes-0-dense-1618603827
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 11.3391 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.3515 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 3.1204 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.2426 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 3.7515 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.5809 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.0135 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.7198 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 1.4463 - sparse_categorical_accuracy: 0.6452 - val_loss: 4.5714 - val_sparse_categorical_accuracy: 0.6667
# Epoch 6/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 1.8164 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.2523 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 1.1563 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.1323 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.4333 - sparse_categorical_accuracy: 0.5806 - val_loss: 2.1252 - val_sparse_categorical_accuracy: 0.6667
# Epoch 9/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 1.7932 - sparse_categorical_accuracy: 0.4839 - val_loss: 2.2361 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 1.4904 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.0389 - val_sparse_categorical_accuracy: 0.8333
# Raks-5-conv-64-nodes-0-dense-1618603832
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 6.9449 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.3293 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 3.1768 - sparse_categorical_accuracy: 0.2581 - val_loss: 2.0939 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 4.3301 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.7681 - val_sparse_categorical_accuracy: 0.1667
# Epoch 4/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.6050 - sparse_categorical_accuracy: 0.3226 - val_loss: 3.1669 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.8243 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.6828 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.5409 - sparse_categorical_accuracy: 0.2581 - val_loss: 0.6828 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 3.1726 - sparse_categorical_accuracy: 0.1935 - val_loss: 1.2112 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.5114 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.5704 - val_sparse_categorical_accuracy: 0.1667
# Epoch 9/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.0505 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.7519 - val_sparse_categorical_accuracy: 0.1667
# Epoch 10/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.8303 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.9191 - val_sparse_categorical_accuracy: 0.0000e+00
# Raks-1-conv-128-nodes-0-dense-1618603837
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 4s 141ms/sample - loss: 1189.8852 - sparse_categorical_accuracy: 0.4839 - val_loss: 38.2608 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 4s 118ms/sample - loss: 253.8034 - sparse_categorical_accuracy: 0.5484 - val_loss: 15.3394 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 3s 110ms/sample - loss: 20.2983 - sparse_categorical_accuracy: 0.8710 - val_loss: 25.5366 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 3s 107ms/sample - loss: 15.5272 - sparse_categorical_accuracy: 0.8065 - val_loss: 36.7061 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 3s 107ms/sample - loss: 0.0034 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9221 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 3s 107ms/sample - loss: 5.7884e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 13.7241 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 3s 107ms/sample - loss: 1.0469e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.9684 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 3s 107ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 11.9178 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 3s 108ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 11.9530 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 3s 110ms/sample - loss: 0.0000e+00 - sparse_categorical_accuracy: 1.0000 - val_loss: 11.9538 - val_sparse_categorical_accuracy: 0.5000
# Raks-2-conv-128-nodes-0-dense-1618603872
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 2s 60ms/sample - loss: 118.0051 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.8217 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 1s 45ms/sample - loss: 3.4833 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.7789 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 1s 46ms/sample - loss: 3.4205 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.8809 - val_sparse_categorical_accuracy: 0.1667
# Epoch 4/10
# 31/31 [==============================] - ETA: 0s - loss: 2.9493 - sparse_categorical_accuracy: 0.275 - 1s 42ms/sample - loss: 2.7590 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.8385 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 1s 47ms/sample - loss: 7.8177 - sparse_categorical_accuracy: 0.5806 - val_loss: 1.8564 - val_sparse_categorical_accuracy: 0.1667
# Epoch 6/10
# 31/31 [==============================] - 1s 47ms/sample - loss: 2.7292 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.7819 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 1s 46ms/sample - loss: 3.2324 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.5980 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 1s 48ms/sample - loss: 22.5837 - sparse_categorical_accuracy: 0.4839 - val_loss: 2.0388 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/10
# 31/31 [==============================] - 1s 41ms/sample - loss: 2.9022 - sparse_categorical_accuracy: 0.1290 - val_loss: 2.0070 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 10/10
# 31/31 [==============================] - 1s 41ms/sample - loss: 3.2667 - sparse_categorical_accuracy: 0.1935 - val_loss: 1.9236 - val_sparse_categorical_accuracy: 0.1667
# Raks-3-conv-128-nodes-0-dense-1618603886
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 39ms/sample - loss: 45.3272 - sparse_categorical_accuracy: 0.4194 - val_loss: 3.8945 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 8.2047 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.0682 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 3.9864 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.8084 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 4.5943 - sparse_categorical_accuracy: 0.5484 - val_loss: 3.2342 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 2.6251 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.9188 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 3.7334 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.8651 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 2.7246 - sparse_categorical_accuracy: 0.6129 - val_loss: 3.3427 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 12.2591 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.6147 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 1.9858 - sparse_categorical_accuracy: 0.6452 - val_loss: 3.8456 - val_sparse_categorical_accuracy: 0.1667
# Epoch 10/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 2.0620 - sparse_categorical_accuracy: 0.5806 - val_loss: 3.0078 - val_sparse_categorical_accuracy: 0.5000
# Raks-4-conv-128-nodes-0-dense-1618603895
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 37ms/sample - loss: 18.4424 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.1291 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 5.2662 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.5707 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 2.4715 - sparse_categorical_accuracy: 0.3871 - val_loss: 0.6351 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 4.7886 - sparse_categorical_accuracy: 0.4839 - val_loss: 0.7531 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 3.1772 - sparse_categorical_accuracy: 0.2258 - val_loss: 2.3970 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 2.2114 - sparse_categorical_accuracy: 0.3226 - val_loss: 0.8918 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 4.2488 - sparse_categorical_accuracy: 0.5161 - val_loss: 2.3409 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 3.7967 - sparse_categorical_accuracy: 0.1935 - val_loss: 2.6536 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 3.5894 - sparse_categorical_accuracy: 0.2903 - val_loss: 2.0957 - val_sparse_categorical_accuracy: 0.1667
# Epoch 10/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 2.1594 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.5648 - val_sparse_categorical_accuracy: 0.3333
# Raks-5-conv-128-nodes-0-dense-1618603904
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 38ms/sample - loss: 17.1241 - sparse_categorical_accuracy: 0.5484 - val_loss: 2.4223 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 4.8861 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.7758 - val_sparse_categorical_accuracy: 0.1667
# Epoch 3/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 3.1456 - sparse_categorical_accuracy: 0.1935 - val_loss: 1.5326 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 2.9732 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.7687 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 2.8254 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.6980 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 1s 26ms/sample - loss: 2.5215 - sparse_categorical_accuracy: 0.1290 - val_loss: 1.4726 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 1s 34ms/sample - loss: 2.1852 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.3531 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 1.9759 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.2778 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 1.7456 - sparse_categorical_accuracy: 0.4839 - val_loss: 0.9073 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 1s 37ms/sample - loss: 3.6315 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.0583 - val_sparse_categorical_accuracy: 0.5000
# Raks-1-conv-32-nodes-1-dense-1618603913
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 763.9433 - sparse_categorical_accuracy: 0.5484 - val_loss: 72.6497 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 1s 20ms/sample - loss: 57.3644 - sparse_categorical_accuracy: 0.5161 - val_loss: 25.7961 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 14.1934 - sparse_categorical_accuracy: 0.6452 - val_loss: 9.3197 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 8.6758 - sparse_categorical_accuracy: 0.7742 - val_loss: 12.5036 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 7.9044 - sparse_categorical_accuracy: 0.8065 - val_loss: 7.7664 - val_sparse_categorical_accuracy: 0.6667
# Epoch 6/10
# 31/31 [==============================] - 1s 16ms/sample - loss: 3.3800 - sparse_categorical_accuracy: 0.9032 - val_loss: 21.9913 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 31.5252 - sparse_categorical_accuracy: 0.6774 - val_loss: 8.1630 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 31.1618 - sparse_categorical_accuracy: 0.7419 - val_loss: 8.9216 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 0.7891 - sparse_categorical_accuracy: 0.9677 - val_loss: 22.1735 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/10
# 31/31 [==============================] - 1s 18ms/sample - loss: 4.1650 - sparse_categorical_accuracy: 0.8387 - val_loss: 9.1200 - val_sparse_categorical_accuracy: 0.1667
# Raks-2-conv-32-nodes-1-dense-1618603919
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 21ms/sample - loss: 17.5407 - sparse_categorical_accuracy: 0.4839 - val_loss: 3.3095 - val_sparse_categorical_accuracy: 0.5000
# Epoch 2/10
# 31/31 [==============================] - 0s 11ms/sample - loss: 3.0146 - sparse_categorical_accuracy: 0.5806 - val_loss: 1.6025 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 1.8538 - sparse_categorical_accuracy: 0.7419 - val_loss: 1.3351 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 0s 12ms/sample - loss: 4.7058 - sparse_categorical_accuracy: 0.6129 - val_loss: 3.3138 - val_sparse_categorical_accuracy: 0.5000
# Epoch 5/10
# 31/31 [==============================] - 0s 11ms/sample - loss: 3.7770 - sparse_categorical_accuracy: 0.8065 - val_loss: 2.6836 - val_sparse_categorical_accuracy: 0.5000
# Epoch 6/10
# 31/31 [==============================] - 0s 12ms/sample - loss: 2.0020 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.7566 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/10
# 31/31 [==============================] - 0s 12ms/sample - loss: 3.2020 - sparse_categorical_accuracy: 0.7419 - val_loss: 1.2495 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 0s 11ms/sample - loss: 0.9097 - sparse_categorical_accuracy: 0.8065 - val_loss: 4.4471 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 0s 11ms/sample - loss: 0.8643 - sparse_categorical_accuracy: 0.8387 - val_loss: 1.5654 - val_sparse_categorical_accuracy: 0.6667
# Epoch 10/10
# 31/31 [==============================] - 0s 11ms/sample - loss: 0.1531 - sparse_categorical_accuracy: 0.9677 - val_loss: 6.2325 - val_sparse_categorical_accuracy: 0.5000
# Raks-3-conv-32-nodes-1-dense-1618603923
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 24ms/sample - loss: 11.2399 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.7255 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 3.5637 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.8659 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.5079 - sparse_categorical_accuracy: 0.4194 - val_loss: 2.2048 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 4/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.3048 - sparse_categorical_accuracy: 0.6129 - val_loss: 3.1495 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.1739 - sparse_categorical_accuracy: 0.5484 - val_loss: 2.6785 - val_sparse_categorical_accuracy: 0.1667
# Epoch 6/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 2.2525 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.3137 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.6082 - sparse_categorical_accuracy: 0.6774 - val_loss: 2.0465 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.3376 - sparse_categorical_accuracy: 0.8387 - val_loss: 2.1882 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 1.8716 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.9942 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 3.2720 - sparse_categorical_accuracy: 0.4839 - val_loss: 2.2604 - val_sparse_categorical_accuracy: 0.6667
# Raks-4-conv-32-nodes-1-dense-1618603927
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 21ms/sample - loss: 16.5392 - sparse_categorical_accuracy: 0.3226 - val_loss: 0.8757 - val_sparse_categorical_accuracy: 0.5000
# Epoch 2/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 6.8421 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.6784 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.9588 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.5642 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.3821 - sparse_categorical_accuracy: 0.2581 - val_loss: 0.7817 - val_sparse_categorical_accuracy: 0.8333
# Epoch 5/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.0630 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.4159 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.4393 - sparse_categorical_accuracy: 0.3226 - val_loss: 3.4504 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 7/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.7512 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.4545 - val_sparse_categorical_accuracy: 0.1667
# Epoch 8/10
# 31/31 [==============================] - 0s 10ms/sample - loss: 2.0650 - sparse_categorical_accuracy: 0.2903 - val_loss: 0.7928 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 3.2851 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.4517 - val_sparse_categorical_accuracy: 0.1667
# Epoch 10/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.5920 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.9345 - val_sparse_categorical_accuracy: 0.6667
# Raks-5-conv-32-nodes-1-dense-1618603930
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 21ms/sample - loss: 6.0517 - sparse_categorical_accuracy: 0.5806 - val_loss: 1.1267 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.6586 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.7446 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.3567 - sparse_categorical_accuracy: 0.1290 - val_loss: 1.3900 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.5953 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.9300 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.6643 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.4579 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.8058 - sparse_categorical_accuracy: 0.1613 - val_loss: 1.8493 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.5446 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.5472 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.2487 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.6354 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.7164 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.4178 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 9ms/sample - loss: 2.3289 - sparse_categorical_accuracy: 0.1613 - val_loss: 1.7577 - val_sparse_categorical_accuracy: 0.0000e+00
# Raks-1-conv-64-nodes-1-dense-1618603934
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 2s 65ms/sample - loss: 2429.7597 - sparse_categorical_accuracy: 0.3871 - val_loss: 544.3555 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 2s 57ms/sample - loss: 144.0291 - sparse_categorical_accuracy: 0.5161 - val_loss: 164.4379 - val_sparse_categorical_accuracy: 0.1667
# Epoch 3/10
# 31/31 [==============================] - 2s 57ms/sample - loss: 420.0260 - sparse_categorical_accuracy: 0.4516 - val_loss: 48.8622 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 2s 62ms/sample - loss: 15.2702 - sparse_categorical_accuracy: 0.5806 - val_loss: 41.0291 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 2s 66ms/sample - loss: 6.2720 - sparse_categorical_accuracy: 0.7742 - val_loss: 44.9059 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 2s 61ms/sample - loss: 2.4501 - sparse_categorical_accuracy: 0.9032 - val_loss: 48.9004 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 2s 60ms/sample - loss: 0.2448 - sparse_categorical_accuracy: 0.9355 - val_loss: 31.7870 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/10
# 31/31 [==============================] - 2s 62ms/sample - loss: 2.4657e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.7800 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 2s 62ms/sample - loss: 1.3328e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.6238 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 2s 61ms/sample - loss: 9.1443e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 30.6228 - val_sparse_categorical_accuracy: 0.3333
# Raks-2-conv-64-nodes-1-dense-1618603953
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 33ms/sample - loss: 200.5728 - sparse_categorical_accuracy: 0.3548 - val_loss: 4.9818 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 3.5465 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.9913 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 16.6838 - sparse_categorical_accuracy: 0.8065 - val_loss: 3.3792 - val_sparse_categorical_accuracy: 0.5000
# Epoch 4/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 1.4540 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.9384 - val_sparse_categorical_accuracy: 0.8333
# Epoch 5/10
# 31/31 [==============================] - 1s 22ms/sample - loss: 0.2178 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.5751 - val_sparse_categorical_accuracy: 0.8333
# Epoch 6/10
# 31/31 [==============================] - 1s 23ms/sample - loss: 0.1760 - sparse_categorical_accuracy: 0.9355 - val_loss: 0.7070 - val_sparse_categorical_accuracy: 0.8333
# Epoch 7/10
# 31/31 [==============================] - 1s 23ms/sample - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9831 - val_sparse_categorical_accuracy: 0.6667
# Epoch 8/10
# 31/31 [==============================] - 1s 23ms/sample - loss: 0.0092 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0486 - val_sparse_categorical_accuracy: 0.6667
# Epoch 9/10
# 31/31 [==============================] - 1s 23ms/sample - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7012 - val_sparse_categorical_accuracy: 0.8333
# Epoch 10/10
# 31/31 [==============================] - 1s 32ms/sample - loss: 6.8134e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9218 - val_sparse_categorical_accuracy: 0.6667
# Raks-3-conv-64-nodes-1-dense-1618603961
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 40ms/sample - loss: 25.8326 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.7992 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 1s 20ms/sample - loss: 5.3408 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.9091 - val_sparse_categorical_accuracy: 0.1667
# Epoch 3/10
# 31/31 [==============================] - 1s 21ms/sample - loss: 4.1730 - sparse_categorical_accuracy: 0.4839 - val_loss: 2.0156 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 2.8809 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.1536 - val_sparse_categorical_accuracy: 0.5000
# Epoch 5/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.2779 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.3062 - val_sparse_categorical_accuracy: 0.5000
# Epoch 6/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 3.5141 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.0664 - val_sparse_categorical_accuracy: 0.8333
# Epoch 7/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 4.0280 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.3195 - val_sparse_categorical_accuracy: 0.1667
# Epoch 8/10
# 31/31 [==============================] - 1s 21ms/sample - loss: 1.9295 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.9225 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 1.7609 - sparse_categorical_accuracy: 0.7419 - val_loss: 1.9116 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 1s 20ms/sample - loss: 1.1625 - sparse_categorical_accuracy: 0.8065 - val_loss: 2.5645 - val_sparse_categorical_accuracy: 0.3333
# Raks-4-conv-64-nodes-1-dense-1618603968
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# ...
# 31/31 [==============================] - 0s 16ms/sample - loss: 2.7436 - sparse_categorical_accuracy: 0.3548 - val_loss: 1.9864 - val_sparse_categorical_accuracy: 0.1667
# Epoch 4/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 3.5518 - sparse_categorical_accuracy: 0.6452 - val_loss: 3.9656 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 4.4414 - sparse_categorical_accuracy: 0.0968 - val_loss: 1.7328 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 0s 16ms/sample - loss: 2.8701 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.7941 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 7/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 2.8079 - sparse_categorical_accuracy: 0.0645 - val_loss: 1.8216 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/10
# 31/31 [==============================] - 1s 16ms/sample - loss: 2.7989 - sparse_categorical_accuracy: 0.0968 - val_loss: 1.9829 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 2.3684 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.6149 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 1.8663 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.6061 - val_sparse_categorical_accuracy: 0.6667
# Raks-4-conv-64-nodes-2-dense-1618604149
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 29ms/sample - loss: 11.4040 - sparse_categorical_accuracy: 0.2258 - val_loss: 2.9664 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 2.8930 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.4397 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 3.2318 - sparse_categorical_accuracy: 0.5806 - val_loss: 1.3715 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 1s 19ms/sample - loss: 3.0551 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.5930 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 1s 18ms/sample - loss: 2.5316 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.7236 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 2.4041 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.3575 - val_sparse_categorical_accuracy: 0.5000
# Epoch 7/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.7073 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.5729 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 0s 16ms/sample - loss: 2.1059 - sparse_categorical_accuracy: 0.5484 - val_loss: 2.5603 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 0s 16ms/sample - loss: 2.0136 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.4223 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 1.6672 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.2559 - val_sparse_categorical_accuracy: 0.6667
# Raks-5-conv-64-nodes-2-dense-1618604154
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 5.9304 - sparse_categorical_accuracy: 0.5484 - val_loss: 1.8850 - val_sparse_categorical_accuracy: 0.5000
# Epoch 2/10
# 31/31 [==============================] - 0s 14ms/sample - loss: 2.6733 - sparse_categorical_accuracy: 0.1613 - val_loss: 2.3125 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/10
# 31/31 [==============================] - 1s 17ms/sample - loss: 2.7334 - sparse_categorical_accuracy: 0.3226 - val_loss: 3.0419 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 3.6750 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.9469 - val_sparse_categorical_accuracy: 0.1667
# Epoch 5/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 3.0900 - sparse_categorical_accuracy: 0.0968 - val_loss: 1.8233 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 4.3142 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.9845 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 7/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 2.8253 - sparse_categorical_accuracy: 0.0645 - val_loss: 1.8066 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/10
# 31/31 [==============================] - 0s 15ms/sample - loss: 2.5334 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.8388 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/10
# 31/31 [==============================] - 0s 12ms/sample - loss: 2.3371 - sparse_categorical_accuracy: 0.1613 - val_loss: 1.6422 - val_sparse_categorical_accuracy: 0.6667
# Epoch 10/10
# 31/31 [==============================] - 0s 13ms/sample - loss: 2.6004 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.7039 - val_sparse_categorical_accuracy: 0.0000e+00
# Raks-1-conv-128-nodes-2-dense-1618604159
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 7s 231ms/sample - loss: 1221.9748 - sparse_categorical_accuracy: 0.1935 - val_loss: 39.6006 - val_sparse_categorical_accuracy: 0.5000
# Epoch 2/10
# 31/31 [==============================] - 6s 209ms/sample - loss: 106.9259 - sparse_categorical_accuracy: 0.6452 - val_loss: 40.8395 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 7s 211ms/sample - loss: 25.4332 - sparse_categorical_accuracy: 0.5161 - val_loss: 5.4553 - val_sparse_categorical_accuracy: 0.1667
# Epoch 4/10
# 31/31 [==============================] - 7s 214ms/sample - loss: 5.6909 - sparse_categorical_accuracy: 0.6774 - val_loss: 4.9632 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/10
# 31/31 [==============================] - 6s 203ms/sample - loss: 1.1994 - sparse_categorical_accuracy: 0.8387 - val_loss: 11.1016 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 7s 221ms/sample - loss: 0.1701 - sparse_categorical_accuracy: 0.9677 - val_loss: 10.3528 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 7s 217ms/sample - loss: 0.5536 - sparse_categorical_accuracy: 0.9032 - val_loss: 10.8987 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 7s 211ms/sample - loss: 7.8075 - sparse_categorical_accuracy: 0.8065 - val_loss: 8.9272 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 7s 215ms/sample - loss: 0.0168 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.5689 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 6s 208ms/sample - loss: 6.1370e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.3473 - val_sparse_categorical_accuracy: 0.3333
# Raks-2-conv-128-nodes-2-dense-1618604226
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 2s 78ms/sample - loss: 38.0186 - sparse_categorical_accuracy: 0.5484 - val_loss: 3.2200 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/10
# 31/31 [==============================] - 2s 63ms/sample - loss: 3.8206 - sparse_categorical_accuracy: 0.3548 - val_loss: 1.2041 - val_sparse_categorical_accuracy: 0.6667
# Epoch 3/10
# 31/31 [==============================] - 2s 65ms/sample - loss: 3.1410 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.6052 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/10
# 31/31 [==============================] - 2s 61ms/sample - loss: 9.1007 - sparse_categorical_accuracy: 0.3871 - val_loss: 2.1446 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/10
# 31/31 [==============================] - 2s 58ms/sample - loss: 2.9768 - sparse_categorical_accuracy: 0.0645 - val_loss: 1.8999 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 2s 58ms/sample - loss: 5.5043 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.8294 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/10
# 31/31 [==============================] - 2s 60ms/sample - loss: 2.9570 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.5268 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/10
# 31/31 [==============================] - 2s 59ms/sample - loss: 33.9203 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.9858 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/10
# 31/31 [==============================] - 2s 64ms/sample - loss: 2.9494 - sparse_categorical_accuracy: 0.0645 - val_loss: 1.9179 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 10/10
# 31/31 [==============================] - 2s 62ms/sample - loss: 2.6037 - sparse_categorical_accuracy: 0.0645 - val_loss: 1.9141 - val_sparse_categorical_accuracy: 0.0000e+00
# Raks-3-conv-128-nodes-2-dense-1618604246
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 47ms/sample - loss: 101.2991 - sparse_categorical_accuracy: 0.3871 - val_loss: 2.0976 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 3.3581 - sparse_categorical_accuracy: 0.4516 - val_loss: 3.6097 - val_sparse_categorical_accuracy: 0.3333
# Epoch 3/10
# 31/31 [==============================] - 1s 39ms/sample - loss: 5.2376 - sparse_categorical_accuracy: 0.3548 - val_loss: 1.8230 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 1s 37ms/sample - loss: 4.9345 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.2087 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 4.3864 - sparse_categorical_accuracy: 0.2258 - val_loss: 1.8642 - val_sparse_categorical_accuracy: 0.1667
# Epoch 6/10
# 31/31 [==============================] - 1s 35ms/sample - loss: 4.5262 - sparse_categorical_accuracy: 0.3226 - val_loss: 2.6021 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 7/10
# 31/31 [==============================] - 1s 34ms/sample - loss: 3.5977 - sparse_categorical_accuracy: 0.3871 - val_loss: 2.0326 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/10
# 31/31 [==============================] - 1s 34ms/sample - loss: 9.7595 - sparse_categorical_accuracy: 0.3226 - val_loss: 1.8185 - val_sparse_categorical_accuracy: 0.1667
# Epoch 9/10
# 31/31 [==============================] - 1s 36ms/sample - loss: 2.3312 - sparse_categorical_accuracy: 0.5806 - val_loss: 1.0887 - val_sparse_categorical_accuracy: 0.6667
# Epoch 10/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 3.0958 - sparse_categorical_accuracy: 0.1290 - val_loss: 1.4921 - val_sparse_categorical_accuracy: 0.1667
# Raks-4-conv-128-nodes-2-dense-1618604257
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 43ms/sample - loss: 8.3301 - sparse_categorical_accuracy: 0.2903 - val_loss: 2.2681 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 3.4394 - sparse_categorical_accuracy: 0.5484 - val_loss: 2.1524 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/10
# 31/31 [==============================] - 1s 32ms/sample - loss: 3.2629 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.6802 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/10
# 31/31 [==============================] - 1s 32ms/sample - loss: 2.6660 - sparse_categorical_accuracy: 0.3871 - val_loss: 1.9682 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 2.7313 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.6526 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/10
# 31/31 [==============================] - 1s 29ms/sample - loss: 2.2907 - sparse_categorical_accuracy: 0.1935 - val_loss: 1.1102 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/10
# 31/31 [==============================] - 1s 29ms/sample - loss: 3.2876 - sparse_categorical_accuracy: 0.4516 - val_loss: 2.2581 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 1.9192 - sparse_categorical_accuracy: 0.3226 - val_loss: 4.1206 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/10
# 31/31 [==============================] - 1s 25ms/sample - loss: 2.3361 - sparse_categorical_accuracy: 0.4194 - val_loss: 2.3414 - val_sparse_categorical_accuracy: 0.3333
# Epoch 10/10
# 31/31 [==============================] - 1s 31ms/sample - loss: 3.0514 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.9418 - val_sparse_categorical_accuracy: 0.0000e+00
# Raks-5-conv-128-nodes-2-dense-1618604267
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 31 samples, validate on 6 samples
# Epoch 1/10
# 31/31 [==============================] - 1s 44ms/sample - loss: 6.9628 - sparse_categorical_accuracy: 0.3548 - val_loss: 2.2193 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 3.6909 - sparse_categorical_accuracy: 0.3226 - val_loss: 2.2409 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/10
# 31/31 [==============================] - 1s 32ms/sample - loss: 2.9755 - sparse_categorical_accuracy: 0.0645 - val_loss: 1.8979 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 4/10
# 31/31 [==============================] - 1s 32ms/sample - loss: 5.0986 - sparse_categorical_accuracy: 0.6452 - val_loss: 1.9064 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/10
# 31/31 [==============================] - 1s 29ms/sample - loss: 2.7582 - sparse_categorical_accuracy: 0.1290 - val_loss: 1.7508 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/10
# 31/31 [==============================] - 1s 33ms/sample - loss: 2.8731 - sparse_categorical_accuracy: 0.3548 - val_loss: 1.9466 - val_sparse_categorical_accuracy: 0.1667
# Epoch 7/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 2.6020 - sparse_categorical_accuracy: 0.2903 - val_loss: 1.3949 - val_sparse_categorical_accuracy: 0.6667
# Epoch 8/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 3.8083 - sparse_categorical_accuracy: 0.3548 - val_loss: 2.4345 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/10
# 31/31 [==============================] - 1s 30ms/sample - loss: 2.4700 - sparse_categorical_accuracy: 0.0645 - val_loss: 2.1683 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 10/10
# 31/31 [==============================] - 1s 28ms/sample - loss: 2.6203 - sparse_categorical_accuracy: 0.2581 - val_loss: 1.6095 - val_sparse_categorical_accuracy: 0.0000e+00

# %%
# model.save('Raks_64x3Cx1D_1.model')

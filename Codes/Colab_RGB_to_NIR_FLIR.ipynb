# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Copy of val_256"
# Out:
# 458_c.tiff  458.tiff  NIR  processed  RGB

# %%
from matplotlib.pyplot import imshow
import numpy as np
import cv2
from keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential
import os
from tqdm import tqdm

Size = 256
c=d=0
img_data = []
path=''
path1 = '/content/drive/MyDrive/Copy of val_256/RGB'
files = os.listdir(path1)
for i in tqdm(files):
    img = cv2.imread(path1 + '/' + i, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (Size, Size))
    img_data.append(img_to_array(img))
    c=c+1
    if(c==200):
      break
# img = cv2.imread('/home/netrunner/Desktop/Raks/val_256/458_c.tiff',1)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# img = cv2.resize(img,(Size,Size))
# img_data.append(img_to_array(img))

img_array = np.reshape(img_data, (len(img_data), Size, Size, 3))
img_array = img_array.astype('float32')/255.

img_data2 = []

path2 ='/content/drive/MyDrive/Copy of val_256/NIR'
files = os.listdir(path2)
for i in tqdm(files):
    img = cv2.imread(path2+'/'+i,1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (Size, Size))
    img_data2.append(img_to_array(img))
    d=d+1
    if(d==200):
      break
# img2 = cv2.imread('/home/netrunner/Desktop/Raks/val_256/458.tiff',1)
# img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
# img2 = cv2.resize (img2,(Size,Size))
# img_data2.append(img_to_array(img2))

img_array2 = np.reshape(img_data2, (len(img_data2), Size, Size, 3))
img_array2 = img_array2.astype('float32')/255.

img_data3 = []

img3 = cv2.imread('/content/drive/MyDrive/Copy of val_256/458_c.tiff', 1)
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img3 = cv2.resize(img3, (Size, Size))
img_data3.append(img_to_array(img3))

img_array3 = np.reshape(img_data3, (len(img_data3), Size, Size, 3))
img_array3 = img_array3.astype('float32')/255.
# Out:
#  41%|████      | 195/476 [00:01<00:02, 107.10it/s]
#  42%|████▏     | 199/476 [00:01<00:02, 136.19it/s]

# %%
model = Sequential()
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same', input_shape = (Size, Size, 3)))
# model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
# model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
# model.add(MaxPooling2D((2,2), padding = 'same'))
# model.add(Conv2D(256, (3, 3), activation = 'relu', padding = 'same'))
# model.add(MaxPooling2D((2, 2), padding = 'same'))
# model.add(Conv2D(256, (3, 3), activation = 'relu', padding = 'same'))
# model.add(Conv2D(512, (3, 3), activation = 'relu', padding = 'same'))
# model.add(Conv2D(512, (3, 3), activation = 'relu', padding = 'same'))
# model.add(Conv2D(256, (3, 3), activation = 'relu', padding = 'same'))

# model.add(MaxPooling2D((2, 2), padding = 'same'))

model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
# model.add(UpSampling2D((2,2)))
model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))
# model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation = 'relu', padding = 'same'))
model.add(Conv2D(32, (3, 3), activation = 'relu', padding = 'same'))

# model.add(UpSampling2D((2, 2)))
# model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))
# model.add(UpSampling2D((2,2)))
# model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
# model.add(UpSampling2D((2,2)))
model.add(Conv2D(3, (3, 3), activation = 'relu', padding = 'same'))

model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])
model.summary()

model.fit(img_array, img_array2, epochs = 100, batch_size = 20, validation_split=0.1, verbose = 1)

model.save('/content/drive/MyDrive/Copy of val_256/model_256_10000.model')
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_134 (Conv2D)          (None, 256, 256, 128)     3584
# _________________________________________________________________
# conv2d_135 (Conv2D)          (None, 256, 256, 128)     147584
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 256, 256, 128)     147584
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 256, 256, 128)     147584
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 256, 256, 64)      73792
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 256, 256, 32)      18464
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 256, 256, 16)      4624
# _________________________________________________________________
# conv2d_141 (Conv2D)          (None, 256, 256, 3)       435
# =================================================================
# Total params: 543,651
# Trainable params: 543,651
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 11s 1s/step - loss: 0.2417 - accuracy: 0.0106 - val_loss: 0.0581 - val_accuracy: 0.0093
# Epoch 2/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.1113 - accuracy: 0.0205 - val_loss: 0.0203 - val_accuracy: 0.1341
# Epoch 3/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0444 - accuracy: 0.2449 - val_loss: 0.0308 - val_accuracy: 0.9583
# Epoch 4/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0339 - accuracy: 0.4542 - val_loss: 0.0287 - val_accuracy: 0.0509
# Epoch 5/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0306 - accuracy: 0.0721 - val_loss: 0.0383 - val_accuracy: 0.0687
# Epoch 6/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0308 - accuracy: 0.0917 - val_loss: 0.0451 - val_accuracy: 0.0676
# Epoch 7/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0298 - accuracy: 0.2912 - val_loss: 0.0413 - val_accuracy: 0.6025
# Epoch 8/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0287 - accuracy: 0.5893 - val_loss: 0.0477 - val_accuracy: 0.7302
# Epoch 9/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0263 - accuracy: 0.4101 - val_loss: 0.0370 - val_accuracy: 0.2846
# Epoch 10/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0250 - accuracy: 0.3107 - val_loss: 0.0370 - val_accuracy: 0.4264
# Epoch 11/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0255 - accuracy: 0.4351 - val_loss: 0.0355 - val_accuracy: 0.5883
# Epoch 12/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0264 - accuracy: 0.4538 - val_loss: 0.0230 - val_accuracy: 0.1453
# Epoch 13/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0264 - accuracy: 0.2801 - val_loss: 0.0314 - val_accuracy: 0.0947
# Epoch 14/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0265 - accuracy: 0.1396 - val_loss: 0.0597 - val_accuracy: 0.0981
# Epoch 15/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0249 - accuracy: 0.3188 - val_loss: 0.0355 - val_accuracy: 0.1904
# Epoch 16/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0245 - accuracy: 0.2917 - val_loss: 0.0237 - val_accuracy: 0.1237
# Epoch 17/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0265 - accuracy: 0.2337 - val_loss: 0.0287 - val_accuracy: 0.2904
# Epoch 18/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0232 - accuracy: 0.3598 - val_loss: 0.0310 - val_accuracy: 0.2501
# Epoch 19/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0233 - accuracy: 0.2904 - val_loss: 0.0316 - val_accuracy: 0.2351
# Epoch 20/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0265 - accuracy: 0.3139 - val_loss: 0.0422 - val_accuracy: 0.2878
# Epoch 21/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0284 - accuracy: 0.3685 - val_loss: 0.0576 - val_accuracy: 0.4671
# Epoch 22/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0267 - accuracy: 0.4082 - val_loss: 0.0377 - val_accuracy: 0.4514
# Epoch 23/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0236 - accuracy: 0.3583 - val_loss: 0.0290 - val_accuracy: 0.3737
# Epoch 24/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0218 - accuracy: 0.3599 - val_loss: 0.0259 - val_accuracy: 0.3754
# Epoch 25/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0238 - accuracy: 0.3165 - val_loss: 0.0349 - val_accuracy: 0.3118
# Epoch 26/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0199 - accuracy: 0.3920 - val_loss: 0.0282 - val_accuracy: 0.5308
# Epoch 27/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0234 - accuracy: 0.3821 - val_loss: 0.0239 - val_accuracy: 0.1566
# Epoch 28/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0231 - accuracy: 0.2084 - val_loss: 0.0316 - val_accuracy: 0.2186
# Epoch 29/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0214 - accuracy: 0.2828 - val_loss: 0.0360 - val_accuracy: 0.3535
# Epoch 30/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0235 - accuracy: 0.4787 - val_loss: 0.0347 - val_accuracy: 0.4015
# Epoch 31/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0225 - accuracy: 0.2686 - val_loss: 0.0302 - val_accuracy: 0.2369
# Epoch 32/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0222 - accuracy: 0.4327 - val_loss: 0.0216 - val_accuracy: 0.0726
# Epoch 33/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0272 - accuracy: 0.1132 - val_loss: 0.0257 - val_accuracy: 0.3492
# Epoch 34/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0214 - accuracy: 0.5329 - val_loss: 0.0292 - val_accuracy: 0.1448
# Epoch 35/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0213 - accuracy: 0.2443 - val_loss: 0.0237 - val_accuracy: 0.1268
# Epoch 36/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0210 - accuracy: 0.1749 - val_loss: 0.0260 - val_accuracy: 0.8849
# Epoch 37/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0240 - accuracy: 0.6314 - val_loss: 0.0355 - val_accuracy: 0.0675
# Epoch 38/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0232 - accuracy: 0.1922 - val_loss: 0.0232 - val_accuracy: 0.7484
# Epoch 39/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0240 - accuracy: 0.5503 - val_loss: 0.0270 - val_accuracy: 0.1867
# Epoch 40/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0204 - accuracy: 0.2733 - val_loss: 0.0238 - val_accuracy: 0.4109
# Epoch 41/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0215 - accuracy: 0.3513 - val_loss: 0.0273 - val_accuracy: 0.4936
# Epoch 42/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0207 - accuracy: 0.4093 - val_loss: 0.0271 - val_accuracy: 0.1216
# Epoch 43/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0237 - accuracy: 0.1584 - val_loss: 0.0360 - val_accuracy: 0.2284
# Epoch 44/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0221 - accuracy: 0.3334 - val_loss: 0.0237 - val_accuracy: 0.5804
# Epoch 45/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0206 - accuracy: 0.3642 - val_loss: 0.0223 - val_accuracy: 0.2068
# Epoch 46/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0213 - accuracy: 0.2829 - val_loss: 0.0309 - val_accuracy: 0.3475
# Epoch 47/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0214 - accuracy: 0.3291 - val_loss: 0.0323 - val_accuracy: 0.2934
# Epoch 48/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0195 - accuracy: 0.2536 - val_loss: 0.0283 - val_accuracy: 0.7213
# Epoch 49/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0221 - accuracy: 0.4379 - val_loss: 0.0294 - val_accuracy: 0.1933
# Epoch 50/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0194 - accuracy: 0.3615 - val_loss: 0.0230 - val_accuracy: 0.6390
# Epoch 51/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0210 - accuracy: 0.2973 - val_loss: 0.0399 - val_accuracy: 0.1298
# Epoch 52/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0238 - accuracy: 0.2484 - val_loss: 0.0413 - val_accuracy: 0.8479
# Epoch 53/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0211 - accuracy: 0.3922 - val_loss: 0.0240 - val_accuracy: 0.1619
# Epoch 54/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0213 - accuracy: 0.3991 - val_loss: 0.0203 - val_accuracy: 0.3682
# Epoch 55/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0223 - accuracy: 0.2421 - val_loss: 0.0208 - val_accuracy: 0.7978
# Epoch 56/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0194 - accuracy: 0.5630 - val_loss: 0.0217 - val_accuracy: 0.1895
# Epoch 57/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0215 - accuracy: 0.2374 - val_loss: 0.0271 - val_accuracy: 0.7092
# Epoch 58/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0200 - accuracy: 0.4817 - val_loss: 0.0223 - val_accuracy: 0.3379
# Epoch 59/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0191 - accuracy: 0.2832 - val_loss: 0.0224 - val_accuracy: 0.4920
# Epoch 60/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0190 - accuracy: 0.4467 - val_loss: 0.0227 - val_accuracy: 0.5372
# Epoch 61/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0206 - accuracy: 0.3245 - val_loss: 0.0207 - val_accuracy: 0.4841
# Epoch 62/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0191 - accuracy: 0.2988 - val_loss: 0.0231 - val_accuracy: 0.4460
# Epoch 63/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0180 - accuracy: 0.4561 - val_loss: 0.0289 - val_accuracy: 0.3407
# Epoch 64/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0187 - accuracy: 0.2600 - val_loss: 0.0191 - val_accuracy: 0.4439
# Epoch 65/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0205 - accuracy: 0.3859 - val_loss: 0.0238 - val_accuracy: 0.2682
# Epoch 66/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0196 - accuracy: 0.3576 - val_loss: 0.0254 - val_accuracy: 0.6505
# Epoch 67/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0166 - accuracy: 0.3949 - val_loss: 0.0193 - val_accuracy: 0.4376
# Epoch 68/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0238 - accuracy: 0.2896 - val_loss: 0.0358 - val_accuracy: 0.1505
# Epoch 69/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0210 - accuracy: 0.2502 - val_loss: 0.0349 - val_accuracy: 0.8028
# Epoch 70/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0193 - accuracy: 0.5212 - val_loss: 0.0250 - val_accuracy: 0.3478
# Epoch 71/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0190 - accuracy: 0.3549 - val_loss: 0.0228 - val_accuracy: 0.5088
# Epoch 72/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0210 - accuracy: 0.3491 - val_loss: 0.0272 - val_accuracy: 0.3500
# Epoch 73/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0187 - accuracy: 0.3954 - val_loss: 0.0283 - val_accuracy: 0.5979
# Epoch 74/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0197 - accuracy: 0.3279 - val_loss: 0.0271 - val_accuracy: 0.2529
# Epoch 75/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0205 - accuracy: 0.3697 - val_loss: 0.0231 - val_accuracy: 0.2249
# Epoch 76/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0197 - accuracy: 0.1699 - val_loss: 0.0219 - val_accuracy: 0.7406
# Epoch 77/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0205 - accuracy: 0.5896 - val_loss: 0.0242 - val_accuracy: 0.1425
# Epoch 78/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0184 - accuracy: 0.2517 - val_loss: 0.0215 - val_accuracy: 0.7054
# Epoch 79/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0186 - accuracy: 0.4545 - val_loss: 0.0182 - val_accuracy: 0.1338
# Epoch 80/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0210 - accuracy: 0.2074 - val_loss: 0.0275 - val_accuracy: 0.7308
# Epoch 81/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0189 - accuracy: 0.4281 - val_loss: 0.0201 - val_accuracy: 0.5015
# Epoch 82/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0179 - accuracy: 0.4727 - val_loss: 0.0227 - val_accuracy: 0.1102
# Epoch 83/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0186 - accuracy: 0.1857 - val_loss: 0.0203 - val_accuracy: 0.6776
# Epoch 84/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0188 - accuracy: 0.4557 - val_loss: 0.0425 - val_accuracy: 0.1267
# Epoch 85/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0196 - accuracy: 0.2759 - val_loss: 0.0350 - val_accuracy: 0.7510
# Epoch 86/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0226 - accuracy: 0.4608 - val_loss: 0.0291 - val_accuracy: 0.1571
# Epoch 87/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0205 - accuracy: 0.3430 - val_loss: 0.0214 - val_accuracy: 0.1949
# Epoch 88/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0187 - accuracy: 0.2327 - val_loss: 0.0226 - val_accuracy: 0.7027
# Epoch 89/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0196 - accuracy: 0.4782 - val_loss: 0.0183 - val_accuracy: 0.2934
# Epoch 90/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0207 - accuracy: 0.2633 - val_loss: 0.0195 - val_accuracy: 0.7288
# Epoch 91/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0186 - accuracy: 0.5103 - val_loss: 0.0209 - val_accuracy: 0.2131
# Epoch 92/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0222 - accuracy: 0.2723 - val_loss: 0.0323 - val_accuracy: 0.4771
# Epoch 93/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0209 - accuracy: 0.3704 - val_loss: 0.0214 - val_accuracy: 0.1321
# Epoch 94/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0250 - accuracy: 0.2240 - val_loss: 0.0240 - val_accuracy: 0.4834
# Epoch 95/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0203 - accuracy: 0.4595 - val_loss: 0.0284 - val_accuracy: 0.6107
# Epoch 96/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0205 - accuracy: 0.4081 - val_loss: 0.0192 - val_accuracy: 0.1563
# Epoch 97/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0250 - accuracy: 0.1945 - val_loss: 0.0224 - val_accuracy: 0.6305
# Epoch 98/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0251 - accuracy: 0.4989 - val_loss: 0.0259 - val_accuracy: 0.0756
# Epoch 99/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0213 - accuracy: 0.2387 - val_loss: 0.0335 - val_accuracy: 0.8454
# Epoch 100/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0187 - accuracy: 0.7225 - val_loss: 0.0259 - val_accuracy: 0.1637
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Copy of val_256/model_256_10000.model/assets

# %%
print("Output")
output = model.predict(img_array3)
cv2.imwrite('/content/drive/MyDrive/Copy of val_256/64_128_128_128_64_32_16.png', output)
imshow(output[0].reshape(Size, Size, 3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Output

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
import imageio
# %matplotlib inline
import os



path=r"/home/netrunner/Videos/test/test3.jpg"
path1=r"/home/netrunner/Videos/crop/cop.jpg"
im= Image.open(path)

width, height = im.size
left = (width/2)-600
top = (height/2)-600
right = (width/2)+600
bottom = (height/2)+600

im1= im.crop((left,top, right, bottom))
im1.save(path1)

# %%
import cv2
import tensorflow as tf
from tensorflow.keras.models import load_model


Categories=["96","97","98","99"]

def prepare(filepath):
    IMG_SIZE=100
    img_array=cv2.imread(filepath)
    new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
    return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,3)


model= tf.keras.models.load_model("64x3Cx1D.model")

prediction= model.predict([prepare('/home/netrunner/Videos/crop/cop.jpg')])
print(prediction)
# print(Categories[int(prediction[0][0])])
# Out:
# [[0. 1. 0. 0.]]

# %%
# from PIL import Image
# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib import cm
# import imageio
# %matplotlib inline
# import os



# img_1=r"/home/netrunner/Videos/test/test1.jpg"
# img_2=r"/home/netrunner/Videos/test/test2.jpg"
# img_3=r"/home/netrunner/Videos/test/test3.jpg"
# path_1=r"/home/netrunner/Videos/crop/test1_crop.jpg"
# path_2=r"/home/netrunner/Videos/crop/test2_crop.jpg"
# path_3=r"/home/netrunner/Videos/crop/test3_crop.jpg"

# im_1= Image.open(img_1)
# im_2= Image.open(img_2)
# im_3= Image.open(img_3)



# width, height = im.size
# left = (width/2)-600
# top = (height/2)-600
# right = (width/2)+600
# bottom = (height/2)+600

# im1= im.crop((left,top, right, bottom))
# im1.save(path1)

# im2= im.crop((left,top, right, bottom))
# im2.save(path_2)

# im3= im.crop((left,top, right, bottom))
# im3.save(path_3)



# import cv2
# import tensorflow as tf
# from tensorflow.keras.models import load_model


# Categories=["96","97","98","99"]

# def prepare(filepath):
#     IMG_SIZE=100
#     img_array=cv2.imread(filepath)
#     new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
#     return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,3)


# model= tf.keras.models.load_model("64x3Cx1D.model")

# prediction= model.predict([prepare('/home/netrunner/Videos/crop/test1_crop.jpg')])
# print(prediction)
# print(Categories[int(prediction[0][0])])

# prediction= model.predict([prepare('/home/netrunner/Videos/crop/test2_crop.jpg')])
# print(prediction)
# print(Categories[int(prediction[0][0])])

# prediction= model.predict([prepare('/home/netrunner/Videos/crop/test3_crop.jpg')])
# print(prediction)
# print(Categories[int(prediction[0][0])])
